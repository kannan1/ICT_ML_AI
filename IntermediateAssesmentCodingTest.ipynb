# %%
#Import Libraies

import pandas as pd

# %%
traindf = pd.read_csv('/content/train_LZdllcl.csv')
testdf = pd.read_csv('/content/test_2umaH9m.csv')
submit = pd.read_csv('/content/sample_submission_M0L0uXE.csv')

# %%
traindf.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
testdf.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# ...

# %%
traindf.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
testdf.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  23490.000000     23490.000000  23490.000000          21678.000000
# mean   39041.399149         1.254236     34.782929              3.339146
# std    22640.809201         0.600910      7.679492              1.263294
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19370.250000         1.000000     29.000000              3.000000
# 50%    38963.500000         1.000000     33.000000              3.000000
# 75%    58690.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score
# count       23490.000000   23490.000000  23490.000000        23490.000000
# mean            5.810387       0.358834      0.022776           63.263133
# std             4.207917       0.479668      0.149191           13.411750
# ...

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
testdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   region                23490 non-null  object
#  3   education             22456 non-null  object
#  4   gender                23490 non-null  object
#  5   recruitment_channel   23490 non-null  object
#  6   no_of_trainings       23490 non-null  int64
#  7   age                   23490 non-null  int64
#  8   previous_year_rating  21678 non-null  float64
#  9   length_of_service     23490 non-null  int64
#  10  KPIs_met >80%         23490 non-null  int64
#  11  awards_won?           23490 non-null  int64
#  12  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# #Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
traindf.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
# Setting the style for the plots
sns.set(style="whitegrid")

# Creating a figure for the plots
fig, ax = plt.subplots(2, 2, figsize=(15, 10))

# Plotting the distributions of the performance indicators
sns.histplot(traindf['previous_year_rating'], ax=ax[0, 0], kde=False, bins=5)
ax[0, 0].set_title('Distribution of Previous Year Rating')

sns.histplot(traindf['KPIs_met >80%'], ax=ax[0, 1], kde=False, bins=2)
ax[0, 1].set_title('Distribution of KPIs Met More Than 80%')

sns.histplot(traindf['awards_won?'], ax=ax[1, 0], kde=False, bins=2)
ax[1, 0].set_title('Distribution of Awards Won')

sns.histplot(traindf['avg_training_score'], ax=ax[1, 1], kde=False, bins=30)
ax[1, 1].set_title('Distribution of Average Training Score')

# Adjusting the layout
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(4, 2, figsize=(15, 20))

# Plotting the relationships between the performance indicators and the 'department' feature
sns.boxplot(x='department', y='previous_year_rating', data=traindf, ax=ax[0, 0])
ax[0, 0].set_title('Previous Year Rating by Department')
ax[0, 0].tick_params(axis='x', rotation=90)

sns.boxplot(x='department', y='avg_training_score', data=traindf, ax=ax[0, 1])
ax[0, 1].set_title('Average Training Score by Department')
ax[0, 1].tick_params(axis='x', rotation=90)

# Plotting the relationships between the performance indicators and the 'education' feature
sns.boxplot(x='education', y='previous_year_rating', data=traindf, ax=ax[1, 0])
ax[1, 0].set_title('Previous Year Rating by Education')

sns.boxplot(x='education', y='avg_training_score', data=traindf, ax=ax[1, 1])
ax[1, 1].set_title('Average Training Score by Education')

# Plotting the relationships between the performance indicators and the 'gender' feature
sns.boxplot(x='gender', y='previous_year_rating', data=traindf, ax=ax[2, 0])
ax[2, 0].set_title('Previous Year Rating by Gender')

sns.boxplot(x='gender', y='avg_training_score', data=traindf, ax=ax[2, 1])
ax[2, 1].set_title('Average Training Score by Gender')

# Plotting the relationships between the performance indicators and the 'recruitment_channel' feature
sns.boxplot(x='recruitment_channel', y='previous_year_rating', data=traindf, ax=ax[3, 0])
ax[3, 0].set_title('Previous Year Rating by Recruitment Channel')

sns.boxplot(x='recruitment_channel', y='avg_training_score', data=traindf, ax=ax[3, 1])
ax[3, 1].set_title('Average Training Score by Recruitment Channel')

# Adjusting the layout
plt.tight_layout()
plt.show()

# %%
# Creating a figure for the plots
fig, ax = plt.subplots(2, 2, figsize=(15, 10))

# Plotting the relationships between the performance indicators and the 'no_of_trainings' feature
sns.scatterplot(x='no_of_trainings', y='previous_year_rating', data=traindf, ax=ax[0, 0])
ax[0, 0].set_title('Previous Year Rating vs. Number of Trainings')

sns.scatterplot(x='no_of_trainings', y='avg_training_score', data=traindf, ax=ax[0, 1])
ax[0, 1].set_title('Average Training Score vs. Number of Trainings')

# Plotting the relationships between the performance indicators and the 'age' feature
sns.scatterplot(x='age', y='previous_year_rating', data=traindf, ax=ax[1, 0])
ax[1, 0].set_title('Previous Year Rating vs. Age')

sns.scatterplot(x='age', y='avg_training_score', data=traindf, ax=ax[1, 1])
ax[1, 1].set_title('Average Training Score vs. Age')

# Adjusting the layout
plt.tight_layout()
plt.show()

# %%
# Select only numerical columns
numerical_data = traindf.select_dtypes(include=['number'])

# Calculate the correlation matrix on numerical data
correlation_matrix = numerical_data.corr()

# Create a figure for the heatmap
plt.figure(figsize=(10, 8))

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)

# Set the title
plt.title('Correlation Matrix of All Numerical Features')

# Display the heatmap
plt.show()

# %% [markdown]
# #PreProcessing

# %% [markdown]
# Missing Values

# %%
traindf.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
testdf.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
# Filling missing values in the 'education' column with the mode (most common value)
traindf['education'].fillna(traindf['education'].mode()[0], inplace=True)
testdf['education'].fillna(testdf['education'].mode()[0], inplace=True)

# Filling missing values in the 'previous_year_rating' column with the median
traindf['previous_year_rating'].fillna(traindf['previous_year_rating'].median(), inplace=True)
testdf['previous_year_rating'].fillna(testdf['previous_year_rating'].median(), inplace=True)

# Checking if all missing values have been filled
print(traindf.isnull().sum())
print(testdf.isnull().sum())
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# dtype: int64
# <ipython-input-17-3baf4fb413fd>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# #Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Selecting the features and the target variable
features = traindf.drop(['employee_id', 'is_promoted'], axis=1)
target = traindf['is_promoted']

# Identifying the categorical features
categorical_features = features.select_dtypes(include=['object']).columns

# Performing one-hot encoding with aligned index
features = pd.get_dummies(features, columns=categorical_features, drop_first=True)

# Splitting the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ((43846, 53), (10962, 53))

# %%
testdf = testdf.drop(['employee_id'], axis=1)

testdf = pd.get_dummies(testdf,columns=categorical_features, drop_first=True)

# %% [markdown]
# #Modeling

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr =LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %%
y_pred_lr
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score,precision_score,recall_score
confusion_matrix(y_test,y_pred_lr)
# Out:
# array([[9980,   74],
#        [ 791,  117]])

# %%
print(accuracy_score(y_test,y_pred_lr))
print(precision_score(y_test,y_pred_lr))
print(recall_score(y_test,y_pred_lr))
print(f1_score(y_test,y_pred_lr))
# Out:
# 0.921091041780697
# 0.612565445026178
# 0.1288546255506608
# 0.21292083712465878

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Define range of k values to try
k_values = range(1, 10)

# Store accuracy scores
accuracy_scores = []

# Train and evaluate for each k
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)

    y_pred = knn.predict(X_test)
    acc = accuracy_score(y_test, y_pred)

    accuracy_scores.append(acc)

# Find best k based on highest accuracy
best_k = k_values[accuracy_scores.index(max(accuracy_scores))]
best_acc = max(accuracy_scores)

print(f"✅ Best k based on accuracy: {best_k}")
print(f"📊 Accuracy at best k: {best_acc:.4f}")
# Out:
# ✅ Best k based on accuracy: 7
# 📊 Accuracy at best k: 0.9257

# %%
accuracy_scores
# Out:
# [0.8879766465973362,
#  0.9221857325305601,
#  0.9185367633643495,
#  0.9244663382594417,
#  0.9237365444261996,
#  0.9248312351760628,
#  0.9257434774676154,
#  0.924922459405218,
#  0.9257434774676154]

# %%
plt.plot(k_values, accuracy_scores, marker='o', linestyle='-', color='blue')
plt.title('KNN Accuracy for Different k Values')
plt.xlabel('k (Number of Neighbors)')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %% [markdown]
# Optimal k value  is 7

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_knn = knn.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred_knn))
print(precision_score(y_test,y_pred_knn))
print(recall_score(y_test,y_pred_knn))
print(f1_score(y_test,y_pred_knn))
# Out:
# 0.9257434774676154
# 0.8263888888888888
# 0.13105726872246695
# 0.2262357414448669

# %% [markdown]
# #SVC

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred_svm = svm.predict(X_test)
accuracy_score(y_test,y_pred_svm)
# Out:
# 0.9171683999270206

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# Initialize and train model
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

# Predict
dt_pred = dt_model.predict(X_test)

# Evaluate
print("📘 Decision Tree Classifier Results:")
print("Accuracy:", accuracy_score(y_test, dt_pred))
print("F1 Score:", f1_score(y_test, dt_pred))
print("Classification Report:\n", classification_report(y_test, dt_pred))
# Out:
# 📘 Decision Tree Classifier Results:
# Accuracy: 0.8972815179711732
# F1 Score: 0.4260958205912334
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     10054
#            1       0.40      0.46      0.43       908
#
#     accuracy                           0.90     10962
#    macro avg       0.67      0.70      0.68     10962
# weighted avg       0.90      0.90      0.90     10962

# %% [markdown]
# Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize and train model
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

# Predict
nb_pred = nb_model.predict(X_test)

# Evaluate
print("📗 Gaussian Naive Bayes Results:")
print("Accuracy:", accuracy_score(y_test, nb_pred))
print("F1 Score:", f1_score(y_test, nb_pred))
print("Classification Report:\n", classification_report(y_test, nb_pred))
# Out:
# 📗 Gaussian Naive Bayes Results:
# Accuracy: 0.3740193395365809
# F1 Score: 0.1832896929302547
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.33      0.49     10054
#            1       0.10      0.85      0.18       908
#
#     accuracy                           0.37     10962
#    macro avg       0.53      0.59      0.34     10962
# weighted avg       0.89      0.37      0.47     10962

# %% [markdown]
# Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
# Base model
dt = DecisionTreeClassifier(random_state=42)

# Parameter grid to tune
param_grid = {
    'max_depth': [3, 5, 10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Grid Search with 5-fold cross-validation
grid_search = GridSearchCV(
    estimator=dt,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1,
    verbose=2
)

# Fit on training data
grid_search.fit(X_train, y_train)

# Best model
best_dt = grid_search.best_estimator_
print("✅ Best Parameters:", grid_search.best_params_)

# Predict on test set
y_pred_tune = best_dt.predict(X_test)

# Evaluate
print("\n📊 Evaluation on Test Data:")
print("Accuracy:", accuracy_score(y_test, y_pred_tune))
print("F1 Score:", f1_score(y_test, y_pred_tune))
print("Classification Report:\n", classification_report(y_test, y_pred_tune))
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# ✅ Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# 📊 Evaluation on Test Data:
# Accuracy: 0.936690384966247
# F1 Score: 0.43300653594771243
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97     10054
#            1       0.84      0.29      0.43       908
#
#     accuracy                           0.94     10962
#    macro avg       0.89      0.64      0.70     10962
# weighted avg       0.93      0.94      0.92     10962

# %% [markdown]
# Fined Tuned Decision Tree Classifier have the heighest accuracy

# %% [markdown]
# Prediction on Test dataset

# %%
y_pred_best = best_dt.predict(testdf)

# %%
y_pred_best
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
submit.head()
# Out:
#    employee_id  is_promoted
# 0         8724            0
# 1        74430            0
# 2        72255            0
# 3        38562            0
# 4        64486            0

# %%
submit["is_promoted"] = y_pred_best

# %%
submit.head()
# Out:
#    employee_id  is_promoted
# 0         8724            0
# 1        74430            0
# 2        72255            0
# 3        38562            0
# 4        64486            0

# %%
submit.to_csv("IntermediateCodeTest.csv", index=False)
